# %%
import pandas as pd
from random import choice

# %%
df = pd.read_csv("settles.acl16.learning_traces.13m.csv")

# %%
print(len(df))
df.head()
# Out:
# 12854226
#    p_recall   timestamp     delta user_id learning_language ui_language  \
# 0       1.0  1362076081  27649635    u:FO                de          en
# 1       0.5  1362076081  27649635    u:FO                de          en
# 2       1.0  1362076081  27649635    u:FO                de          en
# 3       0.5  1362076081  27649635    u:FO                de          en
# 4       1.0  1362076081  27649635    u:FO                de          en
#
#                           lexeme_id                     lexeme_string  \
# 0  76390c1350a8dac31186187e2fe1e178  lernt/lernen<vblex><pri><p3><sg>
# 1  7dfd7086f3671685e2cf1c1da72796d7     die/die<det><def><f><sg><nom>
# 2  35a54c25a2cda8127343f6a82e6f6b7d          mann/mann<n><m><sg><nom>
# 3  0cf63ffe3dda158bc3dbd55682b355ae          frau/frau<n><f><sg><nom>
# 4  84920990d78044db53c1b012f5bf9ab5    das/das<det><def><nt><sg><nom>
#
#    history_seen  history_correct  session_seen  session_correct
# ...

# %%
df.keys()
# Out:
# Index(['p_recall', 'timestamp', 'delta', 'user_id', 'learning_language',
#        'ui_language', 'lexeme_id', 'lexeme_string', 'history_seen',
#        'history_correct', 'session_seen', 'session_correct'],
#       dtype='object')

# %%
df.ui_language.value_counts()
# Out:
# en    7839435
# es    3641179
# pt     949460
# it     424152
# Name: ui_language, dtype: int64

# %%
df.lexeme_id.nunique()
# Out:
# 19279

# %%
len(df)
# Out:
# 12854226

# %%
df.user_id.nunique()
# Out:
# 115222

# %%
max(map(lambda x: (len(x[1]), x[0]), df.groupby("user_id")))
# Out:
# (19194, 'u:bcH_')

# %%
df_user = df[df["user_id"] == "u:bcH_"]

# %%
df_user
# Out:
#           p_recall   timestamp    delta user_id learning_language ui_language  \
# 193803         0.0  1362092353    61015  u:bcH_                en          es
# 193804         1.0  1362092353    83142  u:bcH_                en          es
# 193805         0.0  1362092353    83951  u:bcH_                en          es
# 193806         0.0  1362092353    61191  u:bcH_                en          es
# 193807         0.0  1362092353    83951  u:bcH_                en          es
# ...            ...         ...      ...     ...               ...         ...
# 12504242       1.0  1363066201  2678082  u:bcH_                en          es
# 12504243       1.0  1363066201      144  u:bcH_                en          es
# 12504244       0.0  1363066201      454  u:bcH_                en          es
# 12504245       0.5  1363066201      144  u:bcH_                en          es
# 12504246       0.0  1363066201      454  u:bcH_                en          es
#
# ...

# %%
(set(zip(df["ui_language"], df["learning_language"])))
# Out:
# {('en', 'de'),
#  ('en', 'es'),
#  ('en', 'fr'),
#  ('en', 'it'),
#  ('en', 'pt'),
#  ('es', 'en'),
#  ('it', 'en'),
#  ('pt', 'en')}

# %%
df[["ui_language", "learning_language"]].value_counts()
# Out:
# ui_language  learning_language
# es           en                   3641179
# en           es                   3407689
#              fr                   1873734
#              de                   1452597
# pt           en                    949460
# en           it                    793935
# it           en                    424152
# en           pt                    311480
# dtype: int64

# %%
df_lexeme = choice(list(df_user.groupby("lexeme_id")))[1]
df_lexeme
# Out:
#           p_recall   timestamp   delta user_id learning_language ui_language  \
# 218293         1.0  1362093616  497835  u:bcH_                en          es
# 3697120        1.0  1362376035  282419  u:bcH_                en          es
# 5670804        1.0  1362527590  151556  u:bcH_                en          es
# 8298461        1.0  1362717354  189764  u:bcH_                en          es
# 9326672        1.0  1362806622   89269  u:bcH_                en          es
# 9330659        1.0  1362807186     565  u:bcH_                en          es
# 9335070        0.0  1362807753     567  u:bcH_                en          es
# 9335135        0.0  1362807754       2  u:bcH_                en          es
# 11336242       1.0  1362976169  168415  u:bcH_                en          es
# 12495714       0.0  1363065289   89121  u:bcH_                en          es
#
#                                  lexeme_id       lexeme_string  history_seen  \
# ...

# %%
len(df_lexeme)
# Out:
# 53

# %%
df_lexeme.session_correct.sum()
# Out:
# 25

# %%
df_multilinguals = list(filter(lambda x: x[1].learning_language.nunique() > 1, df.groupby("user_id")))

# %%
len(df_multilinguals)
# Out:
# 2849

# %%
df_multilinguals[324][1]
# Out:
#          p_recall   timestamp   delta user_id learning_language ui_language  \
# 622945        1.0  1362125209  365916  u:cG1X                it          en
# 622946        1.0  1362125209  366077  u:cG1X                it          en
# 622947        1.0  1362125209  365916  u:cG1X                it          en
# 622948        1.0  1362125209  365916  u:cG1X                it          en
# 622949        1.0  1362125209  412429  u:cG1X                it          en
# ...           ...         ...     ...     ...               ...         ...
# 4510452       1.0  1362440569  130825  u:cG1X                it          en
# 4510453       1.0  1362440569  128621  u:cG1X                it          en
# 4510454       1.0  1362440569  128621  u:cG1X                it          en
# 4510455       1.0  1362440569  128621  u:cG1X                it          en
# 4510456       1.0  1362440569  128621  u:cG1X                it          en
#
# ...

# %%
d_mul

# %%
len(df_multilinguals[324][1])
# Out:
# 279

# %%
df_multilinguals[324][1].learning_language.value_counts()
# Out:
# it    230
# fr     49
# Name: learning_language, dtype: int64

# %%
df_lexeme[["p_recall", "history_seen", "history_correct", "session_seen", "session_correct"]]
# Out:
#           p_recall  history_seen  history_correct  session_seen  \
# 211511    0.000000           371              175             1
# 569464    0.000000           372              175             1
# 570925    1.000000           373              175             1
# 1605302   0.000000           374              176             2
# 1606623   0.500000           376              176             2
# 1611349   1.000000           378              177             1
# 2544905   0.000000           379              178             1
# 2565805   1.000000           380              178             1
# 2569907   0.000000           381              179             1
# 2570710   0.000000           382              179             1
# 2572703   0.000000           383              179             1
# 2577352   1.000000           384              179             1
# 2578684   1.000000           385              180             1
# 3673496   1.000000           386              181             1
# ...
